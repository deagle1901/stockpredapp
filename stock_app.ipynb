# %%
#pip install jupyter_plotly_dash
# Out:
# Collecting jupyter_plotly_dash
#   Downloading jupyter_plotly_dash-0.4.3-py3-none-any.whl (29 kB)
# Collecting dpd-static-support
#   Downloading dpd_static_support-0.0.5-py3-none-any.whl (509 kB)
# Collecting nbserverproxy
#   Downloading nbserverproxy-0.8.8-py3-none-any.whl (7.5 kB)
# Collecting django-bootstrap4
#   Downloading django_bootstrap4-3.0.1-py3-none-any.whl (24 kB)
# Collecting dpd-components
#   Downloading dpd_components-0.1.0.tar.gz (4.3 kB)
# Requirement already satisfied: jupyter in c:\anaconda3\lib\site-packages (from jupyter_plotly_dash) (1.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.0-cp37-cp37m-win_amd64.whl (568 kB)
# Collecting django-plotly-dash
#   Downloading django_plotly_dash-1.6.6-py3-none-any.whl (51 kB)
# Requirement already satisfied: notebook in c:\anaconda3\lib\site-packages (from nbserverproxy->jupyter_plotly_dash) (6.0.3)
# Collecting Django>=2.2
#   Downloading Django-3.2.9-py3-none-any.whl (7.9 MB)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in c:\anaconda3\lib\site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.8.2)
# Requirement already satisfied: importlib-metadata<3; python_version < "3.8" in c:\anaconda3\lib\site-packages (from django-bootstrap4->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: jupyter-console in c:\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.1.0)
# Requirement already satisfied: nbconvert in c:\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.6.1)
# Requirement already satisfied: ipykernel in c:\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.1.4)
# Requirement already satisfied: qtconsole in c:\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (4.6.0)
# Requirement already satisfied: ipywidgets in c:\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (7.5.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (19.3.0)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-win_amd64.whl (121 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in c:\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (3.7.4.3)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-win_amd64.whl (82 kB)
# Collecting asynctest==0.13.0; python_version < "3.8"
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-win_amd64.whl (45 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.0-py3-none-any.whl (6.1 kB)
# Collecting dash-core-components
#   Downloading dash_core_components-2.0.0.tar.gz (3.4 kB)
# Collecting dash<1.21.0,>=1.11
#   Downloading dash-1.20.0.tar.gz (77 kB)
# Collecting plotly
#   Downloading plotly-5.3.1-py2.py3-none-any.whl (23.9 MB)
# Requirement already satisfied: Flask>=1.0.2 in c:\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.1)
# Collecting dash-renderer
#   Downloading dash_renderer-1.9.1.tar.gz (1.0 MB)
# Collecting dash-html-components
#   Downloading dash_html_components-2.0.0.tar.gz (3.8 kB)
# Requirement already satisfied: jinja2 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (2.11.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (5.3.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (4.6.1)
# Requirement already satisfied: pyzmq>=17 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (18.1.1)
# Requirement already satisfied: ipython-genutils in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: prometheus-client in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.7.1)
# Requirement already satisfied: tornado>=5.0 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (6.0.3)
# Requirement already satisfied: nbformat in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (5.0.4)
# Requirement already satisfied: Send2Trash in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.8.3)
# Requirement already satisfied: traitlets>=4.2.1 in c:\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (4.3.3)
# Collecting sqlparse>=0.2.2
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pytz in c:\anaconda3\lib\site-packages (from Django>=2.2->django-bootstrap4->jupyter_plotly_dash) (2019.3)
# Requirement already satisfied: soupsieve>=1.2 in c:\anaconda3\lib\site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (1.9.5)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata<3; python_version < "3.8"->django-bootstrap4->jupyter_plotly_dash) (2.2.0)
# Requirement already satisfied: pygments in c:\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (2.5.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (3.0.3)
# Requirement already satisfied: ipython in c:\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (7.12.0)
# Requirement already satisfied: defusedxml in c:\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.3)
# Requirement already satisfied: bleach in c:\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (3.1.0)
# Requirement already satisfied: testpath in c:\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.4.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.5.1)
# Requirement already satisfied: idna>=2.0 in c:\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (2.8)
# Collecting flask-compress
#   Downloading Flask_Compress-1.10.1-py3-none-any.whl (7.9 kB)
# Collecting dash-table==4.11.3
#   Downloading dash_table-4.11.3.tar.gz (1.8 MB)
# Requirement already satisfied: future in c:\anaconda3\lib\site-packages (from dash<1.21.0,>=1.11->django-plotly-dash->jupyter_plotly_dash) (0.18.2)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.15.0)
# Requirement already satisfied: click>=5.1 in c:\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (7.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda3\lib\site-packages (from jinja2->notebook->nbserverproxy->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook->nbserverproxy->jupyter_plotly_dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook->nbserverproxy->jupyter_plotly_dash) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\anaconda3\lib\site-packages (from nbformat->notebook->nbserverproxy->jupyter_plotly_dash) (3.2.0)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from traitlets>=4.2.1->notebook->nbserverproxy->jupyter_plotly_dash) (4.4.1)
# Requirement already satisfied: wcwidth in c:\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyter_plotly_dash) (0.1.8)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.4.3)
# Requirement already satisfied: jedi>=0.10 in c:\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.14.1)
# Requirement already satisfied: setuptools>=18.5 in c:\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (45.2.0.post20200210)
# Requirement already satisfied: pickleshare in c:\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.1.0)
# Requirement already satisfied: webencodings in c:\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp37-cp37m-win_amd64.whl (365 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->nbserverproxy->jupyter_plotly_dash) (0.15.7)
# Requirement already satisfied: parso>=0.5.0 in c:\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.5.2)
# Building wheels for collected packages: dpd-components, dash-core-components, dash, dash-renderer, dash-html-components, dash-table
#   Building wheel for dpd-components (setup.py): started
#   Building wheel for dpd-components (setup.py): finished with status 'done'
#   Created wheel for dpd-components: filename=dpd_components-0.1.0-py3-none-any.whl size=4566 sha256=edb0e604b5e5c1bdf1f8dec32b233b629d38810bf46b462283b4a501a3da3d43
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\37\d1\97\9b1d5f016c47858e080809c277cbe4c3ff27893b855f78915e
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-2.0.0-py3-none-any.whl size=3803 sha256=844cb50494e8c8e85751edf183e3eecd4d32fe1b3503dd58fc3b4db94248b804
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\00\f9\c7\1a6437d794ed753ea9bc9079e761d4fc803a1f1f5d3697b9ec
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.20.0-py3-none-any.whl size=85831 sha256=4ae1d3d16ad65d077dfadb38b351434707c5d1c4263a3f199dc2cdff62493fe4
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\4f\c3\6a\a7cb9cedfdf93e0f0e8db0817ff2646d319afa9e4ca543ef9c
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.1-py3-none-any.whl size=1014876 sha256=e0d3ed6e03b2faaa3a25b12af30b941b68cfc27b2f41ce537bc02332712977ab
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\1a\2f\c0\783c571f9861e5c716b56638926b03fb80bc58991e5a54947d
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-2.0.0-py3-none-any.whl size=4071 sha256=3133dfa66b04913309e15867df566b57188130eb9dda4a95e4e09fa5eb2dd8a6
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\ec\6b\81\05aceabd8b27f724e2c96784016287cc1bfbc349ebfda451de
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.11.3-py3-none-any.whl size=1827616 sha256=e23961f435c8268dba89c01686558e9dd3abb95b40e7c845a82e8be3298ceb69
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\99\5e\cb\e1918e34d079454bad0504e73a9195d9da8cd46605560e6864
# Successfully built dpd-components dash-core-components dash dash-renderer dash-html-components dash-table
# Installing collected packages: dpd-static-support, nbserverproxy, sqlparse, asgiref, Django, django-bootstrap4, dpd-components, charset-normalizer, multidict, yarl, frozenlist, aiosignal, asynctest, async-timeout, aiohttp, dash-core-components, brotli, flask-compress, tenacity, plotly, dash-renderer, dash-html-components, dash-table, dash, django-plotly-dash, jupyter-plotly-dash
# Successfully installed Django-3.2.9 aiohttp-3.8.0 aiosignal-1.2.0 asgiref-3.4.1 async-timeout-4.0.0 asynctest-0.13.0 brotli-1.0.9 charset-normalizer-2.0.7 dash-1.20.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-renderer-1.9.1 dash-table-4.11.3 django-bootstrap4-3.0.1 django-plotly-dash-1.6.6 dpd-components-0.1.0 dpd-static-support-0.0.5 flask-compress-1.10.1 frozenlist-1.2.0 jupyter-plotly-dash-0.4.3 multidict-5.2.0 nbserverproxy-0.8.8 plotly-5.3.1 sqlparse-0.4.2 tenacity-8.0.1 yarl-1.7.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: dash 1.20.0 has requirement dash-core-components==1.16.0, but you'll have dash-core-components 2.0.0 which is incompatible.
# ERROR: dash 1.20.0 has requirement dash-html-components==1.1.3, but you'll have dash-html-components 2.0.0 which is incompatible.

# %%
#pip install dash
# Out:
# Requirement already satisfied: dash in c:\anaconda3\lib\site-packages (1.20.0)
# Requirement already satisfied: plotly in c:\anaconda3\lib\site-packages (from dash) (5.3.1)
# Requirement already satisfied: Flask>=1.0.4 in c:\anaconda3\lib\site-packages (from dash) (1.1.1)
# Requirement already satisfied: future in c:\anaconda3\lib\site-packages (from dash) (0.18.2)
# Collecting dash-html-components==1.1.3
#   Downloading dash_html_components-1.1.3.tar.gz (82 kB)
# Requirement already satisfied: dash-renderer==1.9.1 in c:\anaconda3\lib\site-packages (from dash) (1.9.1)
# Requirement already satisfied: dash-table==4.11.3 in c:\anaconda3\lib\site-packages (from dash) (4.11.3)
# Collecting dash-core-components==1.16.0
#   Downloading dash_core_components-1.16.0.tar.gz (3.5 MB)
# Requirement already satisfied: flask-compress in c:\anaconda3\lib\site-packages (from dash) (1.10.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconda3\lib\site-packages (from plotly->dash) (8.0.1)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from plotly->dash) (1.15.0)
# Requirement already satisfied: click>=5.1 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.1)
# Requirement already satisfied: brotli in c:\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Building wheels for collected packages: dash-html-components, dash-core-components
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.3-py3-none-any.whl size=319473 sha256=04a54c7edb5105de0b3130a10ec2526cfae0372d82bb23f3f8a50d4fc4c931b1
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\7d\75\be\b836bd1c1f92c4823fef293f82375ca448c1fc627ce50acff0
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.16.0-py3-none-any.whl size=3540990 sha256=813bd487ec2a10d75c3d8b8cba5485e8ba7aa55045dea154e4c94ad594fd6524
#   Stored in directory: c:\users\sigma\appdata\local\pip\cache\wheels\6a\50\7e\c440176e48ba46baa157b0f10365f6871acd133460b4e0abe4
# Successfully built dash-html-components dash-core-components
# Installing collected packages: dash-html-components, dash-core-components
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
# Successfully installed dash-core-components-1.16.0 dash-html-components-1.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go
from dash.dependencies import Input, Output
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import warnings
warnings.filterwarnings('ignore')


app = dash.Dash()
server = app.server

scaler=MinMaxScaler(feature_range=(0,1))

df_nse = pd.read_csv("./NSE-TATA.csv")

df_nse["Date"]=pd.to_datetime(df_nse.Date,format="%Y-%m-%d")
df_nse.index=df_nse['Date']


data=df_nse.sort_index(ascending=True,axis=0)
new_data=pd.DataFrame(index=range(0,len(df_nse)),columns=['Date','Close'])

for i in range(0,len(data)):
    new_data["Date"][i]=data['Date'][i]
    new_data["Close"][i]=data["Close"][i]

new_data.index=new_data.Date
new_data.drop("Date",axis=1,inplace=True)

dataset=new_data.values

train=dataset[0:987,:]
valid=dataset[987:,:]

scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)

x_train,y_train=[],[]

for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
    
x_train,y_train=np.array(x_train),np.array(y_train)

x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

model=load_model("saved_lstm_model.h5")

inputs=new_data[len(new_data)-len(valid)-60:].values
inputs=inputs.reshape(-1,1)
inputs=scaler.transform(inputs)

X_test=[]
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
closing_price=model.predict(X_test)
closing_price=scaler.inverse_transform(closing_price)

train=new_data[:987]
valid=new_data[987:]
valid['Predictions']=closing_price



df= pd.read_csv("./stock_data.csv")

app.layout = html.Div([
   
    html.H1("Stock Price Analysis Dashboard", style={"textAlign": "center"}),
   
    dcc.Tabs(id="tabs", children=[
       
        dcc.Tab(label='NSE-TATAGLOBAL Stock Data',children=[
            html.Div([
                html.H2("Actual closing price",style={"textAlign": "center"}),
                dcc.Graph(
                    id="Actual Data",
                    figure={
                        "data":[
                            go.Scatter(
                                x=train.index,
                                y=valid["Close"],
                                mode='markers'
                            )

                        ],
                        "layout":go.Layout(
                            title='scatter plot',
                            xaxis={'title':'Date'},
                            yaxis={'title':'Closing Rate'}
                        )
                    }

                ),
                html.H2("LSTM Predicted closing price",style={"textAlign": "center"}),
                dcc.Graph(
                    id="Predicted Data",
                    figure={
                        "data":[
                            go.Scatter(
                                x=valid.index,
                                y=valid["Predictions"],
                                mode='markers'
                            )

                        ],
                        "layout":go.Layout(
                            title='scatter plot',
                            xaxis={'title':'Date'},
                            yaxis={'title':'Closing Rate'}
                        )
                    }

                )                
            ])                


        ]),
        dcc.Tab(label='Facebook Stock Data', children=[
            html.Div([
                html.H1("Facebook Stocks High vs Lows", 
                        style={'textAlign': 'center'}),
              
                dcc.Dropdown(id='my-dropdown',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'}, 
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['FB'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='highlow'),
                html.H1("Facebook Market Volume", style={'textAlign': 'center'}),
         
                dcc.Dropdown(id='my-dropdown2',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'},
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['FB'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='volume')
            ], className="container"),
        ])


    ])
])


@app.callback(Output('highlow', 'figure'),
              [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    trace2 = []
    for stock in selected_dropdown:
        trace1.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["High"],
                     mode='lines', opacity=0.7, 
                     name=f'High {dropdown[stock]}',textposition='bottom center'))
        trace2.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["Low"],
                     mode='lines', opacity=0.6,
                     name=f'Low {dropdown[stock]}',textposition='bottom center'))
    traces = [trace1, trace2]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data,
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"High and Low Prices for {', '.join(str(dropdown[i]) for i in selected_dropdown)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Price (USD)"})}
    return figure


@app.callback(Output('volume', 'figure'),
              [Input('my-dropdown2', 'value')])
def update_graph(selected_dropdown_value):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    for stock in selected_dropdown_value:
        trace1.append(
          go.Scatter(x=df[df["Stock"] == stock]["Date"],
                     y=df[df["Stock"] == stock]["Volume"],
                     mode='lines', opacity=0.7,
                     name=f'Volume {dropdown[stock]}', textposition='bottom center'))
    traces = [trace1]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data, 
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"Market Volume for {', '.join(str(dropdown[i]) for i in selected_dropdown_value)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M',
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Transactions Volume"})}
    return figure

if __name__=='__main__':
    app.run_server(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
